# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../data/phishing_url_dataset_raw.csv')
df.shape
# Out:
# (235795, 55)

# %%
# Check columns. The features. 
df.columns.tolist()
# Out:
# ['URL',
#  'URLLength',
#  'Domain',
#  'DomainLength',
#  'IsDomainIP',
#  'TLD',
#  'URLSimilarityIndex',
#  'CharContinuationRate',
#  'TLDLegitimateProb',
#  'URLCharProb',
#  'TLDLength',
#  'NoOfSubDomain',
#  'HasObfuscation',
#  'NoOfObfuscatedChar',
#  'ObfuscationRatio',
#  'NoOfLettersInURL',
#  'LetterRatioInURL',
#  'NoOfDegitsInURL',
#  'DegitRatioInURL',
#  'NoOfEqualsInURL',
#  'NoOfQMarkInURL',
#  'NoOfAmpersandInURL',
#  'NoOfOtherSpecialCharsInURL',
#  'SpacialCharRatioInURL',
#  'IsHTTPS',
#  'LineOfCode',
#  'LargestLineLength',
#  'HasTitle',
#  'Title',
#  'DomainTitleMatchScore',
#  'URLTitleMatchScore',
#  'HasFavicon',
#  'Robots',
#  'IsResponsive',
#  'NoOfURLRedirect',
#  'NoOfSelfRedirect',
#  'HasDescription',
#  'NoOfPopup',
#  'NoOfiFrame',
#  'HasExternalFormSubmit',
#  'HasSocialNet',
#  'HasSubmitButton',
#  'HasHiddenFields',
#  'HasPasswordField',
#  'Bank',
#  'Pay',
#  'Crypto',
#  'HasCopyrightInfo',
#  'NoOfImage',
#  'NoOfCSS',
#  'NoOfJS',
# ...

# %%
# Check labels. The values and count.
df['label'].value_counts() # Here we can see the labels, 1 = Legitimate and 0 = Phishing
# Out:
# label
# 1    134850
# 0    100945
# Name: count, dtype: int64

# %%
# Check for missing values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Summary statistics for all numeric columns
df.describe()
# Out:
#            URLLength   DomainLength     IsDomainIP  URLSimilarityIndex  \
# count  235795.000000  235795.000000  235795.000000       235795.000000
# mean       34.573095      21.470396       0.002706           78.430778
# std        41.314153       9.150793       0.051946           28.976055
# min        13.000000       4.000000       0.000000            0.155574
# 25%        23.000000      16.000000       0.000000           57.024793
# 50%        27.000000      20.000000       0.000000          100.000000
# 75%        34.000000      24.000000       0.000000          100.000000
# max      6097.000000     110.000000       1.000000          100.000000
#
#        CharContinuationRate  TLDLegitimateProb    URLCharProb      TLDLength  \
# count         235795.000000      235795.000000  235795.000000  235795.000000
# mean               0.845508           0.260423       0.055747       2.764456
# std                0.216632           0.251628       0.010587       0.599739
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# We look at the class balance, the relationship between 0 and 1
sns.countplot(data=df, x='label')
plt.title('Class balance: 1 = legitimate, 0 = phishing')
plt.show()

# %%
# We will look at the URL length distribution
sns.histplot(df[df['URLLength'] < 200]['URLLength'], bins=50)
plt.title('URL length distribution (excluding extreme outliers)')
plt.show()

# %%
df.groupby('label')[['HasCopyrightInfo', 'NoOfImage', 'NoOfExternalRef', 'Pay']].mean()
# Out:
#        HasCopyrightInfo  NoOfImage  NoOfExternalRef       Pay
# label
# 0              0.057338   0.866492         1.128119  0.060191
# 1              0.808239  44.946600        85.294601  0.369366
